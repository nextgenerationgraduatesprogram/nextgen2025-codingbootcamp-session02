# %% [markdown]
# ### Variables / data types

# %%
ivar = 2025

# %%
print(type(ivar))
# Out:
# <class 'int'>

# %%
fvar = 1500.56

# %%
print(type(fvar))
# Out:
# <class 'float'>

# %%
svar = "CSIRO 2025"

# %%
print(type(svar))
# Out:
# <class 'str'>

# %%
bvar = True

# %%
print(type(bvar))
# Out:
# <class 'bool'>

# %% [markdown]
# ### Data structures

# %% [markdown]
# #### List

# %%
lvar = [2025, "CSIRO", 1500.68, "DATA61"]

# %%
lvar
# Out:
# [2025, 'CSIRO', 1500.68, 'DATA61']

# %%
lvar[0]
# Out:
# 2025

# %%
lvar[3]
# Out:
# 'DATA61'

# %%
lvar.append("Hello")

# %%
lvar
# Out:
# [2025, 'CSIRO', 1500.68, 'DATA61', 'Hello']

# %%
lvar.insert(2,"Hi")

# %%
lvar
# Out:
# [2025, 'CSIRO', 'Hi', 1500.68, 'DATA61', 'Hello']

# %%
lvar.remove("Hello")

# %%
lvar
# Out:
# [2025, 'CSIRO', 'Hi', 1500.68, 'DATA61']

# %%
lvar[0:3] #3-1 = 2
# Out:
# [2025, 'CSIRO', 'Hi']

# %%
lvar[:5]
# Out:
# [2025, 'CSIRO', 'Hi', 1500.68, 'DATA61']

# %%
lvar[:4]
# Out:
# [2025, 'CSIRO', 'Hi', 1500.68]

# %%
lvar[:3]
# Out:
# [2025, 'CSIRO', 'Hi']

# %%
lvar[2:]
# Out:
# ['Hi', 1500.68, 'DATA61']

# %%
lvar2 = ["Yellow", "CSIRO", "Green", "DATA61"]

# %%
lvar2.sort()

# %%
lvar2
# Out:
# ['CSIRO', 'DATA61', 'Green', 'Yellow']

# %%
lvar2.sort(reverse=True)

# %%
lvar2
# Out:
# ['Yellow', 'Green', 'DATA61', 'CSIRO']

# %%
lvar2.clear()

# %%
lvar2
# Out:
# []

# %%
del lvar2

# %%
lvar2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 lvar2
#
# NameError: name 'lvar2' is not defined

# %% [markdown]
# ### Type casting / Type conversion

# %%
ivar = 2025
svar = "CSIRO 2025"
rvar = ivar + svar
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 3
#       1 ivar = 2025
#       2 svar = "CSIRO 2025"
# ----> 3 rvar = ivar + svar
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
snum = str(ivar)

# %%
print(type(snum))
# Out:
# <class 'str'>

# %%
rvar = snum + svar

# %%
rvar
# Out:
# '2025CSIRO 2025'

# %% [markdown]
# ### Conditional and Control

# %%
var1 = 25
var2 = 36
if var1 > var2:
    print("Var1 is greater than Var2")
else:
    print("Var2 is greater than Var1")
# Out:
# Var2 is greater than Var1

# %%
colors = ["Red","Green","Blue","Black","Cyan"]

# %%
colors
# Out:
# ['Red', 'Green', 'Blue', 'Black', 'Cyan']

# %%
for i in colors:
    print(i)
# Out:
# Red
# Green
# Blue
# Black
# Cyan

# %%
for i in colors:
    print(i)
    if i == "Black":
        break
# Out:
# Red
# Green
# Blue
# Black

# %% [markdown]
# ### Dict - Key , Value

# %%
mydict = {"Student No":101,
         "Student Name":"Bhanu",
         "Student Place":"Brisbane"}

# %%
mydict
# Out:
# {'Student No': 101, 'Student Name': 'Bhanu', 'Student Place': 'Brisbane'}

# %%
mydict["Student No"]
# Out:
# 101

# %%
mydict[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 mydict[0]
#
# KeyError: 0

# %%
mydict = {"Student No":101,
         "Student Name":"Bhanu",
         "Student Place":"Brisbane",
         "Colors":["red","green","blue"]}

# %%
mydict["Colors"][1]
# Out:
# 'green'

# %% [markdown]
# ## Data Ingestion

# %% [markdown]
# 1. Import from a flat file - csv / excel
# 2. connecting to a specific data bases
# 3. Import from Json
# 4. Importing from KAGGLE
# 5. Importing from URL / Website

# %%
import pandas as pd
mydata = pd.read_csv("heart.csv")

# %%
mydata
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0      52    1   0       125   212    0        1      168      0      1.0
# 1      53    1   0       140   203    1        0      155      1      3.1
# 2      70    1   0       145   174    0        1      125      1      2.6
# 3      61    1   0       148   203    0        1      161      0      0.0
# 4      62    0   0       138   294    1        1      106      0      1.9
# ...   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 0         2   2     3       0
# ...

# %%
#connecting to a DB
import pyodbc

# %%
#identifying the drivers
for driver in pyodbc.drivers():
    print(driver)
# Out:
# SQL Server
# SQL Server Native Client RDA 11.0
# ODBC Driver 17 for SQL Server
# Microsoft Access Driver (*.mdb, *.accdb)
# Microsoft Excel Driver (*.xls, *.xlsx, *.xlsm, *.xlsb)
# Microsoft Access Text Driver (*.txt, *.csv)
# Microsoft Access dBASE Driver (*.dbf, *.ndx, *.mdx)

# %%
#connection string (driver , server, database, Authentication)
server = 'BHANU_PRAKASH'
database = 'AdventureWorks2022'
cons = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};\
                        SERVER='+ server +';\
                        DATABASE='+ database +';\
                        Trusted_Connection=yes')

# %%
#Cursor
cursor = cons.cursor()

# %%
cursor.execute("select * from Person.CountryRegion")

# %%
cursor.fetchall()
# Out:
# [('AD', 'Andorra', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AE', 'United Arab Emirates', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AF', 'Afghanistan', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AG', 'Antigua and Barbuda', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AI', 'Anguilla', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AL', 'Albania', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AM', 'Armenia', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AN', 'Netherlands Antilles', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AO', 'Angola', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AQ', 'Antarctica', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AR', 'Argentina', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AS', 'American Samoa', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AT', 'Austria', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AU', 'Australia', datetime.datetime(2008, 4, 30, 0, 0)),
#  ('AW', 'Aruba', datetime.datetime(2008, 4, 30, 0, 0)),
# ...

# %%
df = pd.read_sql_query('select * from Person.CountryRegion',cons)
# Out:
# C:\Users\bhanu\AppData\Local\Temp\ipykernel_15672\856982298.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df = pd.read_sql_query('select * from Person.CountryRegion',cons)

# %%
df
# Out:
#     CountryRegionCode                  Name ModifiedDate
# 0                  AD               Andorra   2008-04-30
# 1                  AE  United Arab Emirates   2008-04-30
# 2                  AF           Afghanistan   2008-04-30
# 3                  AG   Antigua and Barbuda   2008-04-30
# 4                  AI              Anguilla   2008-04-30
# ..                ...                   ...          ...
# 233                YE                 Yemen   2008-04-30
# 234                YT               Mayotte   2008-04-30
# 235                ZA          South Africa   2008-04-30
# 236                ZM                Zambia   2008-04-30
# 237                ZW              Zimbabwe   2008-04-30
#
# [238 rows x 3 columns]

# %%
#Json file
import json
with open('schools.json') as file:
    schools = json.load(file)

# %%
schools
# Out:
# [{'name': 'A. Henderson Elementary',
#   'address': '3799 Waterway Dr, Dumfries, VA 22025',
#   'phone': '703-670-2885',
#   'principal': 'Ms. Suzanne Bevans',
#   'grades': 'PK-5',
#   'division': 'Prince William County Public Schools'},
#  {'name': 'A.G. Richardson Elementary',
#   'address': '18370 Simms Dr, Culpeper, VA 22701',
#   'phone': '540-825-0616',
#   'principal': 'Mrs. Susan E. Bridges',
#   'grades': 'PK-5',
#   'division': 'Culpeper County Public Schools'},
#  {'name': 'A.M. Davis Elementary',
#   'address': '415 S Providence Rd, Richmond, VA 23236-3343',
#   'phone': '804-674-1310',
#   'principal': 'Dr. Rachel Foglesong',
#   'grades': 'PK-5',
#   'division': 'Chesterfield County Public Schools'},
#  {'name': 'A.P. Hill Elementary',
#   'address': '1450 Talley Avenue, Petersburg, VA 23803',
#   'phone': '804-862-7002',
#   'principal': 'Mrs. Kori Reddick',
#   'grades': 'KG-5',
#   'division': 'Petersburg Public Schools'},
#  {'name': 'A.S. Rhodes Elementary',
# ...

# %%
import opendatasets as od
dataset = 'https://www.kaggle.com/datasets/aditya0kumar0tiwari/play-badminton'

# %%
od.download(dataset)
# Out:
# Please provide your Kaggle credentials to download this dataset. Learn more: http://bit.ly/kaggle-creds
# Your Kaggle username:
#   bhanudoppala
# Your Kaggle Key:
#   ········
# Dataset URL: https://www.kaggle.com/datasets/aditya0kumar0tiwari/play-badminton
# ...
# 100%|██████████| 399/399 [00:00<00:00, 182kB/s]

# %%
#loading data from website
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://afd.calpoly.edu/web/sample-tables'
resp = requests.get(url)

# %%
resp
# Out:
# <Response [200]>

# %%
resp.text
# Out:
# '<!DOCTYPE html>\r\n<html class="no-js" lang="en" dir="ltr">\r\n\r\n<head>\r\n\t<!--\r\nCal Poly Web Template v2.0.0\r\nCode maintained by\r\nInformation Technology Services\r\nCalifornia Polytechnic State University\r\nSan Luis Obispo, CA 93407\r\n-->\r\n\t<meta charset="UTF-8">\r\n\t<meta http-equiv="X-UA-Compatible" content="IE=Edge">\r\n\t<meta name="viewport" content="width=device-width, initial-scale=1.0"/> \r\n\r\n\t<title>Sample Tables - Web - Cal Poly</title>\n\r\n\t<meta http-equiv="content-language" content="en" />\r\n\t<meta name="language" content="en" />\r\n\t<meta name="msapplication-config" content="none" />\r\n\r\n\t<meta name="codebase" content="AFD-2.0" />\r\n\r\n\r\n\t<meta name="Description" content="As stewards of the University resources, we provide high quality, efficient support and planning services as an integral part of the campus community in support of student learning." />\r\n\t<meta name="Keywords" content="Cal Poly, Administration, AFD, Finance, Polic
# ...

# %%
BeautifulSoup(resp.text)
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en">
# <head>
# <!--
# Cal Poly Web Template v2.0.0
# Code maintained by
# Information Technology Services
# California Polytechnic State University
# San Luis Obispo, CA 93407
# -->
# <meta charset="utf-8"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <title>Sample Tables - Web - Cal Poly</title>
# <meta content="en" http-equiv="content-language"/>
# <meta content="en" name="language"/>
# <meta content="none" name="msapplication-config"/>
# <meta content="AFD-2.0" name="codebase"/>
# <meta content="As stewards of the University resources, we provide high quality, efficient support and planning services as an integral part of the campus community in support of student learning." name="Description"/>
# <meta content="Cal Poly, Administration, AFD, Finance, Police, Budget, Facilities, Fiscal, HR, Risk, Technology, Corporation" name="Keywords"/>
# ...

# %%
bful = BeautifulSoup(resp.text)

# %%
print(bful.prettify())
# Out:
# <!DOCTYPE html>
# <html class="no-js" dir="ltr" lang="en">
#  <head>
#   <!--
# Cal Poly Web Template v2.0.0
# Code maintained by
# Information Technology Services
# California Polytechnic State University
# San Luis Obispo, CA 93407
# -->
#   <meta charset="utf-8"/>
#   <meta content="IE=Edge" http-equiv="X-UA-Compatible"/>
#   <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
#   <title>
#    Sample Tables - Web - Cal Poly
#   </title>
#   <meta content="en" http-equiv="content-language"/>
#   <meta content="en" name="language"/>
#   <meta content="none" name="msapplication-config"/>
#   <meta content="AFD-2.0" name="codebase"/>
#   <meta content="As stewards of the University resources, we provide high quality, efficient support and planning services as an integral part of the campus community in support of student learning." name="Description"/>
# ...

# %%
print(bful.title)
# Out:
# <title>Sample Tables - Web - Cal Poly</title>

# %%
for link in bful.find_all('a'):
    print(link.get('href'))
# Out:
# #content
# http://www.calpoly.edu/
# /
# None
# /services
# https://myportal.calpoly.edu
# /web/
# https://wiki.calpoly.edu/display/usr/Web+Editing+-+Accessible+Documents
# /web/style-guide
# mailto:afd-web@calpoly.edu?subject=%5Bwebsite name%5D - %5Bdescriptor%5D
# /
# /web/
# None
# http://warc.calpoly.edu/accessibility/508indepth/rowcolumn.html
# None
# #
# #
# #
# #
# #
# #
# #
# None
# None
# #
# #
# None
# #
# #
# #
# #
# #
# #
# #
# #
# None
# #
# #
# #
# http://maps.calpoly.edu/?vlist=058-0
# mailto:afd-web@calpoly.edu
# https://twitter.com/insidecalpoly/
# https://www.instagram.com/insidecalpoly/
# https://www.facebook.com/insidecalpoly/
# https://security.calpoly.edu
# https://security.calpoly.edu/content/policies/standards/classification/index
# https://wiki.calpoly.edu/x/DouFDw
# https://tech.calpoly.edu/services
# http://www.calpoly.edu/
# https://www.calpoly.edu/privacy/
# https://accessibility.calpoly.edu/website-accessibility-statement
# ...

# %%
import pandas as pd

# %%
tables = pd.io.html.read_html(url)

# %%
tables
# Out:
# [                                         Description  \
#  0                            Academic Senate Meeting
#  1                               Commencement Meeting
#  2                                     Dean's Council
#  3                            Committee on Committees
#  4  Lorem ipsum dolor sit amet, consectetuer adipi...
#  5                                  Lorem ipsum dolor
#
#                                                  Date  \
#  0                                       May 25, 2205
#  1                                  December 15, 2205
#  2                                   February 1, 2206
#  3                                      March 3, 2206
#  4  Lorem ipsum dolor sit amet, consectetuer adipi...
#  5                                  Lorem ipsum dolor
#
#                                              Location
#  0                                 Building 99 Room 1
#  1                                Building 42 Room 10
# ...

# %%
tables[0]
# Out:
#                                          Description  \
# 0                            Academic Senate Meeting
# 1                               Commencement Meeting
# 2                                     Dean's Council
# 3                            Committee on Committees
# 4  Lorem ipsum dolor sit amet, consectetuer adipi...
# 5                                  Lorem ipsum dolor
#
#                                                 Date  \
# 0                                       May 25, 2205
# 1                                  December 15, 2205
# 2                                   February 1, 2206
# 3                                      March 3, 2206
# 4  Lorem ipsum dolor sit amet, consectetuer adipi...
# 5                                  Lorem ipsum dolor
#
#                                             Location
# 0                                 Building 99 Room 1
# 1                                Building 42 Room 10
# 2                                 Building 35 Room 5
# ...

# %%
tables[5]
# Out:
#    NAME OF SYSTEM OR PORTAL CHANNEL  \
# 0              Personal Information
# 1              Personal Information
# 2              Personal Information
# 3              Personal Information
# 4               Group Leave Balance
# 5                Leave/CTO Balances
# 6               Faculty Course Info
# 7               Faculty Course Info
# 8               Faculty Course Info
# 9               Faculty Course Info
# 10              Faculty Course Info
# 11              Faculty Course Info
# 12              Enrollment Planning
# 13                      Student Pay
# 14                         PolyData
# 15                         PolyData
# 16                      PolyProfile
# 17                      PolyProfile
# 18                      PolyProfile
#
#                      NAME OF SYSTEM OR ACTIVITY STATUS DURING OUTAGE  \
# 0                                     Addresses            View Only
# 1                                         Names            View Only
# ...

# %%
tables[5].to_csv("School_data_30.01.2025")
